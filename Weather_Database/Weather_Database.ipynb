# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import random 
from citipy import citipy
import requests as req
# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-180,180,size=2000)
lats_lngs = zip(lats,lngs)

lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = req.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | dezhou
# City not found. Skipping...
# Processing Record 3 of Set 1 | sentyabrskiy
# Processing Record 4 of Set 1 | faanui
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | kismayo
# Processing Record 7 of Set 1 | madang
# Processing Record 8 of Set 1 | vila velha
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | westport
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | carutapera
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | narsaq
# City not found. Skipping...
# Processing Record 16 of Set 1 | taolanaro
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | clyde river
# Processing Record 19 of Set 1 | maragogi
# Processing Record 20 of Set 1 | codrington
# City not found. Skipping...
# Processing Record 21 of Set 1 | vaitupu
# Processing Record 22 of Set 1 | hasaki
# Processing Record 23 of Set 1 | new baltimore
# Processing Record 24 of Set 1 | ulaangom
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | koindu
# City not found. Skipping...
# Processing Record 27 of Set 1 | dien bien
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | yeghegnut
# Processing Record 30 of Set 1 | inta
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | wageningen
# Processing Record 34 of Set 1 | bayan
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | sitka
# City not found. Skipping...
# Processing Record 38 of Set 1 | nizhneyansk
# Processing Record 39 of Set 1 | cururupu
# City not found. Skipping...
# Processing Record 40 of Set 1 | mys shmidta
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | aksu
# Processing Record 43 of Set 1 | mgachi
# Processing Record 44 of Set 1 | saskylakh
# Processing Record 45 of Set 1 | guerrero negro
# City not found. Skipping...
# Processing Record 46 of Set 1 | attawapiskat
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | semey
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | berdigestyakh
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | bredasdorp
# City not found. Skipping...
# Processing Record 3 of Set 2 | barentsburg
# Processing Record 4 of Set 2 | moose factory
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | helong
# Processing Record 8 of Set 2 | torbay
# Processing Record 9 of Set 2 | georgiyevskoye
# Processing Record 10 of Set 2 | pingdu
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | sao filipe
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | flinders
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | qasigiannguit
# Processing Record 18 of Set 2 | cabo san lucas
# City not found. Skipping...
# Processing Record 19 of Set 2 | belushya guba
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | high level
# Processing Record 23 of Set 2 | iqaluit
# Processing Record 24 of Set 2 | cedar city
# Processing Record 25 of Set 2 | leavenworth
# Processing Record 26 of Set 2 | gloversville
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | aklavik
# Processing Record 29 of Set 2 | kudahuvadhoo
# Processing Record 30 of Set 2 | vila franca do campo
# Processing Record 31 of Set 2 | lianzhou
# Processing Record 32 of Set 2 | gardez
# Processing Record 33 of Set 2 | ulundi
# Processing Record 34 of Set 2 | puerto baquerizo moreno
# Processing Record 35 of Set 2 | beringovskiy
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | saint-honore
# Processing Record 38 of Set 2 | mago
# Processing Record 39 of Set 2 | vanavara
# Processing Record 40 of Set 2 | boyuibe
# Processing Record 41 of Set 2 | nouadhibou
# Processing Record 42 of Set 2 | cervo
# Processing Record 43 of Set 2 | dikson
# Processing Record 44 of Set 2 | aswan
# Processing Record 45 of Set 2 | halifax
# Processing Record 46 of Set 2 | saint george
# Processing Record 47 of Set 2 | ndungu
# Processing Record 48 of Set 2 | skjold
# Processing Record 49 of Set 2 | yellowknife
# City not found. Skipping...
# Processing Record 50 of Set 2 | marcona
# Processing Record 1 of Set 3 | victoria
# Processing Record 2 of Set 3 | itarema
# Processing Record 3 of Set 3 | loiza
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | husavik
# City not found. Skipping...
# Processing Record 6 of Set 3 | ondorhaan
# Processing Record 7 of Set 3 | mount gambier
# Processing Record 8 of Set 3 | polazna
# City not found. Skipping...
# Processing Record 9 of Set 3 | bargal
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | berlevag
# Processing Record 12 of Set 3 | japura
# Processing Record 13 of Set 3 | palu
# Processing Record 14 of Set 3 | redwater
# Processing Record 15 of Set 3 | nelson bay
# City not found. Skipping...
# Processing Record 16 of Set 3 | chaochou
# Processing Record 17 of Set 3 | mantenopolis
# Processing Record 18 of Set 3 | komsomolskiy
# Processing Record 19 of Set 3 | bandarbeyla
# Processing Record 20 of Set 3 | kalabo
# Processing Record 21 of Set 3 | ushuaia
# Processing Record 22 of Set 3 | lompoc
# Processing Record 23 of Set 3 | vila
# Processing Record 24 of Set 3 | yelanskiy
# Processing Record 25 of Set 3 | nishihara
# Processing Record 26 of Set 3 | dunedin
# Processing Record 27 of Set 3 | valparaiso
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | taoudenni
# Processing Record 30 of Set 3 | chimoio
# Processing Record 31 of Set 3 | butaritari
# Processing Record 32 of Set 3 | avera
# Processing Record 33 of Set 3 | erzin
# City not found. Skipping...
# Processing Record 34 of Set 3 | illoqqortoormiut
# Processing Record 35 of Set 3 | bengkulu
# Processing Record 36 of Set 3 | talnakh
# Processing Record 37 of Set 3 | kashipur
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | turukhansk
# Processing Record 40 of Set 3 | makakilo city
# Processing Record 41 of Set 3 | nikolskoye
# Processing Record 42 of Set 3 | kita
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | camacha
# Processing Record 45 of Set 3 | port-cartier
# Processing Record 46 of Set 3 | hwange
# Processing Record 47 of Set 3 | provideniya
# Processing Record 48 of Set 3 | pali
# Processing Record 49 of Set 3 | san jose
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | asosa
# Processing Record 2 of Set 4 | karasjok
# Processing Record 3 of Set 4 | peace river
# Processing Record 4 of Set 4 | mahebourg
# Processing Record 5 of Set 4 | ostrovnoy
# Processing Record 6 of Set 4 | san policarpo
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | castro
# City not found. Skipping...
# Processing Record 9 of Set 4 | stoyba
# Processing Record 10 of Set 4 | kangaatsiaq
# Processing Record 11 of Set 4 | porto belo
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | lagoa
# Processing Record 14 of Set 4 | sao joao da barra
# Processing Record 15 of Set 4 | ngunguru
# Processing Record 16 of Set 4 | nanortalik
# Processing Record 17 of Set 4 | kodiak
# Processing Record 18 of Set 4 | walvis bay
# Processing Record 19 of Set 4 | pokhara
# Processing Record 20 of Set 4 | bonavista
# Processing Record 21 of Set 4 | arraial do cabo
# Processing Record 22 of Set 4 | port hueneme
# City not found. Skipping...
# Processing Record 23 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 4 | shibarghan
# Processing Record 25 of Set 4 | visby
# City not found. Skipping...
# Processing Record 26 of Set 4 | parras
# Processing Record 27 of Set 4 | verkhnevilyuysk
# Processing Record 28 of Set 4 | ponta delgada
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | escanaba
# Processing Record 31 of Set 4 | pangai
# Processing Record 32 of Set 4 | constitucion
# City not found. Skipping...
# Processing Record 33 of Set 4 | marathopolis
# Processing Record 34 of Set 4 | gazanjyk
# Processing Record 35 of Set 4 | coquimbo
# Processing Record 36 of Set 4 | honningsvag
# Processing Record 37 of Set 4 | upernavik
# Processing Record 38 of Set 4 | yar-sale
# Processing Record 39 of Set 4 | columbus
# Processing Record 40 of Set 4 | puerto rico
# Processing Record 41 of Set 4 | sept-iles
# Processing Record 42 of Set 4 | longyearbyen
# Processing Record 43 of Set 4 | maun
# Processing Record 44 of Set 4 | barrow
# Processing Record 45 of Set 4 | wamba
# City not found. Skipping...
# Processing Record 46 of Set 4 | lolua
# Processing Record 47 of Set 4 | kodar
# Processing Record 48 of Set 4 | ola
# Processing Record 49 of Set 4 | myitkyina
# Processing Record 50 of Set 4 | bereda
# Processing Record 1 of Set 5 | assiniboia
# Processing Record 2 of Set 5 | ponta do sol
# Processing Record 3 of Set 5 | mantua
# City not found. Skipping...
# Processing Record 4 of Set 5 | utiroa
# Processing Record 5 of Set 5 | redlands
# Processing Record 6 of Set 5 | cockburn town
# Processing Record 7 of Set 5 | henties bay
# Processing Record 8 of Set 5 | prince rupert
# Processing Record 9 of Set 5 | malazgirt
# Processing Record 10 of Set 5 | north auburn
# Processing Record 11 of Set 5 | tuatapere
# Processing Record 12 of Set 5 | karratha
# Processing Record 13 of Set 5 | khandbari
# Processing Record 14 of Set 5 | mar del plata
# Processing Record 15 of Set 5 | fortuna
# Processing Record 16 of Set 5 | santa isabel do rio negro
# Processing Record 17 of Set 5 | adrar
# Processing Record 18 of Set 5 | bilibino
# Processing Record 19 of Set 5 | raisen
# Processing Record 20 of Set 5 | matina
# Processing Record 21 of Set 5 | egvekinot
# Processing Record 22 of Set 5 | manturovo
# Processing Record 23 of Set 5 | ixtapa
# Processing Record 24 of Set 5 | severo-kurilsk
# Processing Record 25 of Set 5 | faya
# Processing Record 26 of Set 5 | castelo do piaui
# Processing Record 27 of Set 5 | yumen
# Processing Record 28 of Set 5 | bathsheba
# Processing Record 29 of Set 5 | sao miguel do araguaia
# Processing Record 30 of Set 5 | versalles
# Processing Record 31 of Set 5 | caluquembe
# Processing Record 32 of Set 5 | agadez
# Processing Record 33 of Set 5 | three hills
# Processing Record 34 of Set 5 | lebu
# Processing Record 35 of Set 5 | nome
# Processing Record 36 of Set 5 | rio grande
# Processing Record 37 of Set 5 | hami
# Processing Record 38 of Set 5 | hambantota
# Processing Record 39 of Set 5 | dhidhdhoo
# Processing Record 40 of Set 5 | haines junction
# Processing Record 41 of Set 5 | uige
# Processing Record 42 of Set 5 | dingle
# Processing Record 43 of Set 5 | la palma
# Processing Record 44 of Set 5 | pacific grove
# Processing Record 45 of Set 5 | grindavik
# Processing Record 46 of Set 5 | porto novo
# Processing Record 47 of Set 5 | akranes
# Processing Record 48 of Set 5 | san carlos de bariloche
# Processing Record 49 of Set 5 | falun
# Processing Record 50 of Set 5 | los andes
# City not found. Skipping...
# Processing Record 1 of Set 6 | barbar
# Processing Record 2 of Set 6 | zyryanka
# Processing Record 3 of Set 6 | igarka
# Processing Record 4 of Set 6 | maslova pristan
# Processing Record 5 of Set 6 | gagino
# Processing Record 6 of Set 6 | boa esperanca
# Processing Record 7 of Set 6 | hervey bay
# Processing Record 8 of Set 6 | pisco
# Processing Record 9 of Set 6 | san miguel
# Processing Record 10 of Set 6 | deputatskiy
# Processing Record 11 of Set 6 | zlocieniec
# Processing Record 12 of Set 6 | san cristobal
# Processing Record 13 of Set 6 | kajaani
# Processing Record 14 of Set 6 | saldanha
# Processing Record 15 of Set 6 | vao
# City not found. Skipping...
# Processing Record 16 of Set 6 | aflu
# Processing Record 17 of Set 6 | arman
# Processing Record 18 of Set 6 | zambezi
# Processing Record 19 of Set 6 | fort nelson
# Processing Record 20 of Set 6 | birjand
# City not found. Skipping...
# Processing Record 21 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 6 | louisbourg
# Processing Record 23 of Set 6 | alva
# Processing Record 24 of Set 6 | ilulissat
# Processing Record 25 of Set 6 | saint anthony
# Processing Record 26 of Set 6 | aasiaat
# Processing Record 27 of Set 6 | palmer
# City not found. Skipping...
# Processing Record 28 of Set 6 | port ellen
# Processing Record 29 of Set 6 | wau
# Processing Record 30 of Set 6 | nalut
# Processing Record 31 of Set 6 | ormara
# Processing Record 32 of Set 6 | tasiilaq
# Processing Record 33 of Set 6 | englewood
# City not found. Skipping...
# Processing Record 34 of Set 6 | grand river south east
# Processing Record 35 of Set 6 | manjacaze
# Processing Record 36 of Set 6 | bac lieu
# Processing Record 37 of Set 6 | leticia
# Processing Record 38 of Set 6 | asau
# Processing Record 39 of Set 6 | cascais
# Processing Record 40 of Set 6 | la asuncion
# Processing Record 41 of Set 6 | bestobe
# Processing Record 42 of Set 6 | areosa
# Processing Record 43 of Set 6 | ozinki
# Processing Record 44 of Set 6 | sidi bin nur
# Processing Record 45 of Set 6 | mabaruma
# Processing Record 46 of Set 6 | lorengau
# Processing Record 47 of Set 6 | kosa
# City not found. Skipping...
# Processing Record 48 of Set 6 | tsihombe
# Processing Record 49 of Set 6 | morlaix
# Processing Record 50 of Set 6 | alta gracia
# Processing Record 1 of Set 7 | pokrovsk
# Processing Record 2 of Set 7 | baykit
# Processing Record 3 of Set 7 | grand-santi
# Processing Record 4 of Set 7 | jalu
# Processing Record 5 of Set 7 | atar
# City not found. Skipping...
# Processing Record 6 of Set 7 | yirol
# Processing Record 7 of Set 7 | minot
# Processing Record 8 of Set 7 | tautira
# Processing Record 9 of Set 7 | maceio
# Processing Record 10 of Set 7 | anadyr
# City not found. Skipping...
# Processing Record 11 of Set 7 | kamenskoye
# Processing Record 12 of Set 7 | bwanga
# Processing Record 13 of Set 7 | zhongshu
# Processing Record 14 of Set 7 | durham
# Processing Record 15 of Set 7 | nha trang
# City not found. Skipping...
# Processing Record 16 of Set 7 | samusu
# Processing Record 17 of Set 7 | ilhabela
# Processing Record 18 of Set 7 | conde
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | billings
# Processing Record 21 of Set 7 | murray bridge
# Processing Record 22 of Set 7 | sestri levante
# Processing Record 23 of Set 7 | manadhoo
# Processing Record 24 of Set 7 | arrecife
# Processing Record 25 of Set 7 | yulara
# Processing Record 26 of Set 7 | mezen
# Processing Record 27 of Set 7 | miracema do tocantins
# Processing Record 28 of Set 7 | aparecida do taboado
# Processing Record 29 of Set 7 | luderitz
# Processing Record 30 of Set 7 | andenes
# Processing Record 31 of Set 7 | seka
# Processing Record 32 of Set 7 | eureka
# Processing Record 33 of Set 7 | salalah
# Processing Record 34 of Set 7 | vardo
# Processing Record 35 of Set 7 | luwuk
# Processing Record 36 of Set 7 | geraldton
# Processing Record 37 of Set 7 | mocajuba
# Processing Record 38 of Set 7 | kirovskiy
# Processing Record 39 of Set 7 | chuy
# Processing Record 40 of Set 7 | ulaanbaatar
# Processing Record 41 of Set 7 | muroto
# Processing Record 42 of Set 7 | terrace bay
# Processing Record 43 of Set 7 | ndola
# Processing Record 44 of Set 7 | pevek
# Processing Record 45 of Set 7 | port lincoln
# Processing Record 46 of Set 7 | cherskiy
# City not found. Skipping...
# Processing Record 47 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 7 | saleaula
# Processing Record 49 of Set 7 | paamiut
# Processing Record 50 of Set 7 | sehithwa
# Processing Record 1 of Set 8 | owando
# Processing Record 2 of Set 8 | gao
# Processing Record 3 of Set 8 | muros
# Processing Record 4 of Set 8 | lavrentiya
# Processing Record 5 of Set 8 | port blair
# Processing Record 6 of Set 8 | villa carlos paz
# Processing Record 7 of Set 8 | vestmannaeyjar
# Processing Record 8 of Set 8 | sergeyevka
# Processing Record 9 of Set 8 | cassilandia
# Processing Record 10 of Set 8 | wanning
# Processing Record 11 of Set 8 | cocorit
# Processing Record 12 of Set 8 | buala
# Processing Record 13 of Set 8 | moree
# Processing Record 14 of Set 8 | drezdenko
# Processing Record 15 of Set 8 | inhambane
# Processing Record 16 of Set 8 | aksarka
# Processing Record 17 of Set 8 | zemio
# Processing Record 18 of Set 8 | gongzhuling
# Processing Record 19 of Set 8 | nipawin
# Processing Record 20 of Set 8 | esperance
# Processing Record 21 of Set 8 | hurth
# Processing Record 22 of Set 8 | skjervoy
# Processing Record 23 of Set 8 | leh
# Processing Record 24 of Set 8 | kasungu
# Processing Record 25 of Set 8 | kabalo
# Processing Record 26 of Set 8 | touros
# Processing Record 27 of Set 8 | myra
# Processing Record 28 of Set 8 | nyurba
# Processing Record 29 of Set 8 | isangel
# Processing Record 30 of Set 8 | acapulco
# Processing Record 31 of Set 8 | hun
# Processing Record 32 of Set 8 | boqueron
# Processing Record 33 of Set 8 | belyy yar
# Processing Record 34 of Set 8 | pemangkat
# Processing Record 35 of Set 8 | dustlik
# Processing Record 36 of Set 8 | matara
# Processing Record 37 of Set 8 | murighiol
# Processing Record 38 of Set 8 | rio gallegos
# Processing Record 39 of Set 8 | marienburg
# Processing Record 40 of Set 8 | saint-joseph
# Processing Record 41 of Set 8 | dong hoi
# Processing Record 42 of Set 8 | kotaparh
# Processing Record 43 of Set 8 | cayenne
# Processing Record 44 of Set 8 | manzil kamil
# Processing Record 45 of Set 8 | caravelas
# Processing Record 46 of Set 8 | cozumel
# Processing Record 47 of Set 8 | verkhnyaya inta
# Processing Record 48 of Set 8 | ahtopol
# Processing Record 49 of Set 8 | orikhove
# Processing Record 50 of Set 8 | escarcega
# Processing Record 1 of Set 9 | tiksi
# Processing Record 2 of Set 9 | korla
# Processing Record 3 of Set 9 | zhigansk
# Processing Record 4 of Set 9 | rabat
# Processing Record 5 of Set 9 | dauriya
# Processing Record 6 of Set 9 | souillac
# Processing Record 7 of Set 9 | richards bay
# Processing Record 8 of Set 9 | kuala kedah
# Processing Record 9 of Set 9 | inuvik
# Processing Record 10 of Set 9 | carbonia
# Processing Record 11 of Set 9 | chapais
# Processing Record 12 of Set 9 | cascas
# Processing Record 13 of Set 9 | tura
# City not found. Skipping...
# Processing Record 14 of Set 9 | khonsar
# Processing Record 15 of Set 9 | am timan
# Processing Record 16 of Set 9 | tocopilla
# Processing Record 17 of Set 9 | klaksvik
# Processing Record 18 of Set 9 | torres
# Processing Record 19 of Set 9 | khilok
# Processing Record 20 of Set 9 | silver city
# Processing Record 21 of Set 9 | maniitsoq
# Processing Record 22 of Set 9 | rohru
# Processing Record 23 of Set 9 | harbour breton
# Processing Record 24 of Set 9 | tahoua
# Processing Record 25 of Set 9 | tiznit
# Processing Record 26 of Set 9 | daru
# Processing Record 27 of Set 9 | mossendjo
# Processing Record 28 of Set 9 | poddorye
# Processing Record 29 of Set 9 | tarbes
# Processing Record 30 of Set 9 | luan
# Processing Record 31 of Set 9 | usvyaty
# Processing Record 32 of Set 9 | liberal
# Processing Record 33 of Set 9 | college
# Processing Record 34 of Set 9 | kalmunai
# Processing Record 35 of Set 9 | mykolayiv
# Processing Record 36 of Set 9 | neiafu
# Processing Record 37 of Set 9 | kuminskiy
# Processing Record 38 of Set 9 | protvino
# Processing Record 39 of Set 9 | kahului
# Processing Record 40 of Set 9 | terrace
# Processing Record 41 of Set 9 | liuzhou
# Processing Record 42 of Set 9 | vredendal
# Processing Record 43 of Set 9 | kavieng
# Processing Record 44 of Set 9 | ahuatempan
# Processing Record 45 of Set 9 | mayumba
# Processing Record 46 of Set 9 | bousse
# Processing Record 47 of Set 9 | mastic beach
# Processing Record 48 of Set 9 | broome
# Processing Record 49 of Set 9 | opuwo
# City not found. Skipping...
# Processing Record 50 of Set 9 | ust-kamchatsk
# Processing Record 1 of Set 10 | tazovskiy
# City not found. Skipping...
# Processing Record 2 of Set 10 | palabuhanratu
# Processing Record 3 of Set 10 | borogontsy
# Processing Record 4 of Set 10 | kiruna
# Processing Record 5 of Set 10 | gat
# Processing Record 6 of Set 10 | oni
# Processing Record 7 of Set 10 | pestovo
# Processing Record 8 of Set 10 | umm lajj
# Processing Record 9 of Set 10 | liku
# Processing Record 10 of Set 10 | kargasok
# Processing Record 11 of Set 10 | xuddur
# Processing Record 12 of Set 10 | maldonado
# Processing Record 13 of Set 10 | hanting
# Processing Record 14 of Set 10 | miraflores
# Processing Record 15 of Set 10 | rosetta
# Processing Record 16 of Set 10 | zhanaozen
# Processing Record 17 of Set 10 | beaumont
# Processing Record 18 of Set 10 | edd
# City not found. Skipping...
# Processing Record 19 of Set 10 | bokspits
# Processing Record 20 of Set 10 | nanjing
# Processing Record 21 of Set 10 | liverpool
# Processing Record 22 of Set 10 | diamantino
# City not found. Skipping...
# Processing Record 23 of Set 10 | otradinskiy
# Processing Record 24 of Set 10 | pucara
# Processing Record 25 of Set 10 | qaqortoq
# Processing Record 26 of Set 10 | shingu
# Processing Record 27 of Set 10 | bocaiuva
# City not found. Skipping...
# Processing Record 28 of Set 10 | sorvag
# Processing Record 29 of Set 10 | kirakira
# Processing Record 30 of Set 10 | solano
# Processing Record 31 of Set 10 | sabang
# Processing Record 32 of Set 10 | talara
# Processing Record 33 of Set 10 | whitehorse
# Processing Record 34 of Set 10 | hauterive
# Processing Record 35 of Set 10 | chengzihe
# Processing Record 36 of Set 10 | kyrksaeterora
# Processing Record 37 of Set 10 | tezu
# Processing Record 38 of Set 10 | urumqi
# City not found. Skipping...
# Processing Record 39 of Set 10 | artyk
# Processing Record 40 of Set 10 | necochea
# Processing Record 41 of Set 10 | ankazoabo
# Processing Record 42 of Set 10 | klyuchi
# Processing Record 43 of Set 10 | lima
# Processing Record 44 of Set 10 | goma
# Processing Record 45 of Set 10 | madinat sittah uktubar
# Processing Record 46 of Set 10 | samarai
# Processing Record 47 of Set 10 | portland
# City not found. Skipping...
# Processing Record 48 of Set 10 | karaul
# Processing Record 49 of Set 10 | cojocna
# City not found. Skipping...
# Processing Record 50 of Set 10 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 1 of Set 11 | mahaicony
# Processing Record 2 of Set 11 | ludvika
# Processing Record 3 of Set 11 | san quintin
# Processing Record 4 of Set 11 | jimo
# Processing Record 5 of Set 11 | sidi ali
# Processing Record 6 of Set 11 | yinchuan
# Processing Record 7 of Set 11 | horsham
# Processing Record 8 of Set 11 | ureki
# Processing Record 9 of Set 11 | santiago del estero
# Processing Record 10 of Set 11 | puerto ayacucho
# Processing Record 11 of Set 11 | port hardy
# Processing Record 12 of Set 11 | sao jose da coroa grande
# Processing Record 13 of Set 11 | vysokogornyy
# Processing Record 14 of Set 11 | labis
# Processing Record 15 of Set 11 | alice town
# Processing Record 16 of Set 11 | pangnirtung
# Processing Record 17 of Set 11 | san andres
# Processing Record 18 of Set 11 | havelock
# Processing Record 19 of Set 11 | grand gaube
# Processing Record 20 of Set 11 | lozova
# Processing Record 21 of Set 11 | ibra
# Processing Record 22 of Set 11 | pahrump
# Processing Record 23 of Set 11 | ourem
# Processing Record 24 of Set 11 | mokhsogollokh
# Processing Record 25 of Set 11 | padang
# Processing Record 26 of Set 11 | yuksekova
# Processing Record 27 of Set 11 | humaita
# City not found. Skipping...
# Processing Record 28 of Set 11 | haibowan
# Processing Record 29 of Set 11 | bolkhov
# Processing Record 30 of Set 11 | were ilu
# Processing Record 31 of Set 11 | lisakovsk
# Processing Record 32 of Set 11 | raudeberg
# Processing Record 33 of Set 11 | kochubey
# Processing Record 34 of Set 11 | zlynka
# Processing Record 35 of Set 11 | puerto escondido
# Processing Record 36 of Set 11 | arcachon
# Processing Record 37 of Set 11 | teguise
# Processing Record 38 of Set 11 | ninghai
# Processing Record 39 of Set 11 | meadow lake
# Processing Record 40 of Set 11 | calamar
# Processing Record 41 of Set 11 | kavaratti
# Processing Record 42 of Set 11 | montevideo
# Processing Record 43 of Set 11 | rundu
# Processing Record 44 of Set 11 | uni
# Processing Record 45 of Set 11 | cooma
# Processing Record 46 of Set 11 | ternate
# Processing Record 47 of Set 11 | pak chong
# Processing Record 48 of Set 11 | bombay
# Processing Record 49 of Set 11 | riberalta
# Processing Record 50 of Set 11 | usinsk
# Processing Record 1 of Set 12 | bektemir
# Processing Record 2 of Set 12 | oktyabrskiy
# Processing Record 3 of Set 12 | kodinsk
# Processing Record 4 of Set 12 | kloulklubed
# Processing Record 5 of Set 12 | port hedland
# Processing Record 6 of Set 12 | marawi
# Processing Record 7 of Set 12 | salta
# Processing Record 8 of Set 12 | kihei
# Processing Record 9 of Set 12 | antsla
# Processing Record 10 of Set 12 | port macquarie
# Processing Record 11 of Set 12 | nizwa
# Processing Record 12 of Set 12 | kargopol
# Processing Record 13 of Set 12 | tabuk
# Processing Record 14 of Set 12 | warwick
# City not found. Skipping...
# Processing Record 15 of Set 12 | do rud
# Processing Record 16 of Set 12 | okha
# Processing Record 17 of Set 12 | garden city
# Processing Record 18 of Set 12 | manjeri
# Processing Record 19 of Set 12 | playa vicente
# Processing Record 20 of Set 12 | kruisfontein
# Processing Record 21 of Set 12 | keskin
# City not found. Skipping...
# Processing Record 22 of Set 12 | sinkat
# Processing Record 23 of Set 12 | palamos
# Processing Record 24 of Set 12 | kemri
# Processing Record 25 of Set 12 | kashi
# Processing Record 26 of Set 12 | phonhong
# City not found. Skipping...
# Processing Record 27 of Set 12 | tir pol
# Processing Record 28 of Set 12 | aguimes
# Processing Record 29 of Set 12 | camocim
# Processing Record 30 of Set 12 | altamira
# Processing Record 31 of Set 12 | chernyshevskiy
# Processing Record 32 of Set 12 | mount isa
# Processing Record 33 of Set 12 | aitape
# Processing Record 34 of Set 12 | shoreline
# Processing Record 35 of Set 12 | guanica
# Processing Record 36 of Set 12 | mahabad
# Processing Record 37 of Set 12 | sozimskiy
# Processing Record 38 of Set 12 | mitsamiouli
# Processing Record 39 of Set 12 | puerto penasco
# Processing Record 40 of Set 12 | beloha
# Processing Record 41 of Set 12 | ahipara
# Processing Record 42 of Set 12 | miles city
# Processing Record 43 of Set 12 | alofi
# City not found. Skipping...
# Processing Record 44 of Set 12 | tungkang
# Processing Record 45 of Set 12 | meulaboh
# Processing Record 46 of Set 12 | pareora
# Processing Record 47 of Set 12 | kivertsi
# Processing Record 48 of Set 12 | yaan
# Processing Record 49 of Set 12 | hobyo
# Processing Record 50 of Set 12 | alyangula
# Processing Record 1 of Set 13 | labuhan
# Processing Record 2 of Set 13 | zlobin
# Processing Record 3 of Set 13 | varna
# Processing Record 4 of Set 13 | almaznyy
# Processing Record 5 of Set 13 | olavarria
# Processing Record 6 of Set 13 | hazleton
# Processing Record 7 of Set 13 | naze
# Processing Record 8 of Set 13 | beira
# Processing Record 9 of Set 13 | katsuura
# Processing Record 10 of Set 13 | saint-pierre
# Processing Record 11 of Set 13 | belaya gora
# Processing Record 12 of Set 13 | mineiros
# Processing Record 13 of Set 13 | paramonga
# Processing Record 14 of Set 13 | hargeysa
# Processing Record 15 of Set 13 | presidencia roque saenz pena
# Processing Record 16 of Set 13 | innisfail
# Processing Record 17 of Set 13 | springbok
# Processing Record 18 of Set 13 | tiruchchendur
# Processing Record 19 of Set 13 | payo
# Processing Record 20 of Set 13 | hokitika
# Processing Record 21 of Set 13 | belmonte
# Processing Record 22 of Set 13 | bodden town
# Processing Record 23 of Set 13 | mogadishu
# Processing Record 24 of Set 13 | ketchikan
# Processing Record 25 of Set 13 | carnot
# Processing Record 26 of Set 13 | qingyuan
# Processing Record 27 of Set 13 | bayji
# Processing Record 28 of Set 13 | ust-ilimsk
# Processing Record 29 of Set 13 | manono
# City not found. Skipping...
# Processing Record 30 of Set 13 | a
# Processing Record 31 of Set 13 | dolores
# Processing Record 32 of Set 13 | cutervo
# Processing Record 33 of Set 13 | kaseda
# Processing Record 34 of Set 13 | alugan
# City not found. Skipping...
# Processing Record 35 of Set 13 | dolbeau
# Processing Record 36 of Set 13 | gwanda
# Processing Record 37 of Set 13 | biu
# Processing Record 38 of Set 13 | srandakan
# Processing Record 39 of Set 13 | harqalah
# Processing Record 40 of Set 13 | comodoro rivadavia
# Processing Record 41 of Set 13 | seymchan
# Processing Record 42 of Set 13 | atambua
# Processing Record 43 of Set 13 | balkhash
# Processing Record 44 of Set 13 | poum
# Processing Record 45 of Set 13 | buchmany
# City not found. Skipping...
# Processing Record 46 of Set 13 | burica
# Processing Record 47 of Set 13 | colquechaca
# Processing Record 48 of Set 13 | sawakin
# Processing Record 49 of Set 13 | severo-yeniseyskiy
# Processing Record 50 of Set 13 | tonstad
# Processing Record 1 of Set 14 | christchurch
# Processing Record 2 of Set 14 | sur
# Processing Record 3 of Set 14 | srednekolymsk
# Processing Record 4 of Set 14 | tizapan el alto
# Processing Record 5 of Set 14 | urdoma
# Processing Record 6 of Set 14 | batamshinskiy
# Processing Record 7 of Set 14 | road town
# Processing Record 8 of Set 14 | bay city
# Processing Record 9 of Set 14 | gouyave
# City not found. Skipping...
# Processing Record 10 of Set 14 | tabiauea
# Processing Record 11 of Set 14 | nowy tomysl
# Processing Record 12 of Set 14 | carsamba
# Processing Record 13 of Set 14 | tabas
# Processing Record 14 of Set 14 | pochutla
# Processing Record 15 of Set 14 | covington
# Processing Record 16 of Set 14 | mehamn
# Processing Record 17 of Set 14 | robe
# Processing Record 18 of Set 14 | islamkot
# Processing Record 19 of Set 14 | turkistan
# Processing Record 20 of Set 14 | chifeng
# Processing Record 21 of Set 14 | quemado de guines
# Processing Record 22 of Set 14 | lewisporte
# Processing Record 23 of Set 14 | thap than
# Processing Record 24 of Set 14 | svetlyy
# Processing Record 25 of Set 14 | trairi
# Processing Record 26 of Set 14 | alghero
# Processing Record 27 of Set 14 | falam
# Processing Record 28 of Set 14 | kushmurun
# Processing Record 29 of Set 14 | san ramon
# Processing Record 30 of Set 14 | magadan
# Processing Record 31 of Set 14 | zlitan
# Processing Record 32 of Set 14 | matamoros
# Processing Record 33 of Set 14 | synevyr
# Processing Record 34 of Set 14 | sampit
# Processing Record 35 of Set 14 | barpathar
# Processing Record 36 of Set 14 | tambacounda
# Processing Record 37 of Set 14 | nantucket
# City not found. Skipping...
# Processing Record 38 of Set 14 | miranorte
# Processing Record 39 of Set 14 | antofagasta
# Processing Record 40 of Set 14 | pyapon
# Processing Record 41 of Set 14 | tallahassee
# Processing Record 42 of Set 14 | coahuayana
# Processing Record 43 of Set 14 | kosai
# City not found. Skipping...
# Processing Record 44 of Set 14 | mudyuga
# Processing Record 45 of Set 14 | sao gabriel da cachoeira
# Processing Record 46 of Set 14 | ishigaki
# City not found. Skipping...
# Processing Record 47 of Set 14 | nguiu
# Processing Record 48 of Set 14 | sisimiut
# City not found. Skipping...
# Processing Record 49 of Set 14 | safwah
# Processing Record 50 of Set 14 | sola
# Processing Record 1 of Set 15 | waipawa
# Processing Record 2 of Set 15 | lethem
# Processing Record 3 of Set 15 | madras
# Processing Record 4 of Set 15 | wad rawah
# City not found. Skipping...
# Processing Record 5 of Set 15 | cockburn harbour
# Processing Record 6 of Set 15 | sumbe
# Processing Record 7 of Set 15 | baijiantan
# Processing Record 8 of Set 15 | mathbaria
# Processing Record 9 of Set 15 | bani
# Processing Record 10 of Set 15 | tsabong
# Processing Record 11 of Set 15 | villa rosario
# Processing Record 12 of Set 15 | hofn
# Processing Record 13 of Set 15 | belinskiy
# Processing Record 14 of Set 15 | kaoma
# Processing Record 15 of Set 15 | wajima
# Processing Record 16 of Set 15 | lagos
# Processing Record 17 of Set 15 | manokwari
# City not found. Skipping...
# Processing Record 18 of Set 15 | wangdiphodrang
# Processing Record 19 of Set 15 | talakan
# Processing Record 20 of Set 15 | bereznik
# Processing Record 21 of Set 15 | deogarh
# Processing Record 22 of Set 15 | teacapan
# Processing Record 23 of Set 15 | banjar
# Processing Record 24 of Set 15 | natchez
# Processing Record 25 of Set 15 | jijiga
# Processing Record 26 of Set 15 | gushikawa
# Processing Record 27 of Set 15 | areka
# Processing Record 28 of Set 15 | northam
# Processing Record 29 of Set 15 | vostok
# Processing Record 30 of Set 15 | pitsunda
# City not found. Skipping...
# Processing Record 31 of Set 15 | lokken verk
# Processing Record 32 of Set 15 | soyo
# Processing Record 33 of Set 15 | baoying
# Processing Record 34 of Set 15 | ulladulla
# Processing Record 35 of Set 15 | kutum
# Processing Record 36 of Set 15 | chipata
# Processing Record 37 of Set 15 | sao felix do xingu
# Processing Record 38 of Set 15 | evensk
# Processing Record 39 of Set 15 | ornskoldsvik
# Processing Record 40 of Set 15 | caohai
# Processing Record 41 of Set 15 | doka
# Processing Record 42 of Set 15 | jumla
# Processing Record 43 of Set 15 | falkenberg
# Processing Record 44 of Set 15 | warri
# Processing Record 45 of Set 15 | kupang
# Processing Record 46 of Set 15 | chamba
# Processing Record 47 of Set 15 | bairiki
# Processing Record 48 of Set 15 | manzanillo
# Processing Record 49 of Set 15 | takoradi
# Processing Record 50 of Set 15 | grootfontein
# Processing Record 1 of Set 16 | sidhi
# Processing Record 2 of Set 16 | plettenberg bay
# Processing Record 3 of Set 16 | tosya
# Processing Record 4 of Set 16 | amapa
# Processing Record 5 of Set 16 | iskateley
# Processing Record 6 of Set 16 | hovd
# Processing Record 7 of Set 16 | hualmay
# Processing Record 8 of Set 16 | leningradskiy
# Processing Record 9 of Set 16 | miramar
# City not found. Skipping...
# Processing Record 10 of Set 16 | roches noires
# Processing Record 11 of Set 16 | hamilton
# Processing Record 12 of Set 16 | te anau
# Processing Record 13 of Set 16 | goderich
# Processing Record 14 of Set 16 | lasa
# Processing Record 15 of Set 16 | akureyri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_database_df = pd.DataFrame(city_data)
city_database_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hobart      AU -42.8794  147.3294     40.26        96          20
# 1      Dezhou      CN  37.4486  116.2925     79.99        96          97
# 2      Faanui      PF -16.4833 -151.7500     77.11        69          82
# 3     Rikitea      PF -23.1203 -134.9692     72.34        69         100
# 4     Kismayo      SO  -0.3582   42.5454     74.64        78          52
# 5      Madang      PG  -5.2246  145.7966     79.88        85          86
# 6  Vila Velha      BR -20.3297  -40.2925     75.15        81           0
# 7     Mataura      NZ -46.1927  168.8643     39.47        71           8
# 8  Chokurdakh      RU  70.6333  147.9167     50.00        48         100
# 9    Westport      US  41.1415  -73.3579     87.49        66           0
#
#    Wind Speed Current Description
# 0        9.22          few clouds
# 1        5.64     overcast clouds
# 2       23.64       broken clouds
# 3       32.14     overcast clouds
# 4       18.63       broken clouds
# 5        2.98     overcast clouds
# 6       16.11           clear sky
# 7        8.57           clear sky
# 8       16.13     overcast clouds
# 9       16.11           clear sky

# %%
len(city_database_df)
# Out:
# 705

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_database_df.to_csv(output_data_file, index_label="City_ID")
